# %%
import nltk
import pandas as pd
from textblob import TextBlob
from collections import Counter
from sklearn.preprocessing import OneHotEncoder
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import csv
import string
from nltk.tokenize import PunktSentenceTokenizer
from nltk.corpus import state_union

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
codeswitched = pd.read_csv("Codeswitched.csv")

# %%
codeswitched
# Out:
#        count  hate_speech  offensive_language  neither  class  \
# 0          3            1                   1        2      2
# 1          3            1                   1        2      2
# 2          3            1                   1        2      2
# 3          3            1                   1        2      2
# 4          3            1                   1        2      2
# ...      ...          ...                 ...      ...    ...
# 50170      4            2                   1        1      0
# 50171      4            2                   1        1      0
# 50172      5            3                   0        2      0
# 50173      4            2                   0        2      0
# 50174      4            3                   1        0      0
#
#                                                    tweet
# 0      kindly say bickering to kikuyus and kalenjins....
# 1      kindly remind them that we do not have thoroug...
# ...

# %%
# function to print all the hashtags in a text
def extract_hashtags(text):
     
    # initializing hashtag_list variable
    hashtag_list = []
    
    hashtags = ""
     
    # splitting the text into words
    for word in text.split():
         
        # checking the first character of every word
        if word[0] == '#':
                         
            # adding the word to the hashtag_list
            hashtag_list.append(word[1:])
            
    for hashtag in hashtag_list:
        hashtags = hashtags+","+hashtag
        
    return hashtags

# %%
##To get adjective and adverbs in text
def textblob_adj(text):
    adj_count = 0
    adj_count = 0
    blobed = TextBlob(text)
    counts = Counter(tag for word, tag in blobed.tags)
    adj_list = []
    adv_list = []
    adj_tag_list = ['JJ','JJR','JJS']
    adv_tag_list = ['RB','RBR','RBS']
    for (a,b) in blobed.tags:
        if b in adj_tag_list:
            adj_list.append(a)
            adj_count+=1
        elif b in adv_tag_list:
            adv_list.append(a)
            adj_count+=1
        else:
            pas
    return adj_list,adv_list

# %%
tweets = codeswitched['tweet']

# %%
hash = []
for tweet in tweets:
    # initializing hashtag_list variable
    hashtag_list = []
    
    hashtags = ""
     
    # splitting the text into words
    for word in tweet.split():
         
        # checking the first character of every word
        if word[0] == '#':
                         
            # adding the word to the hashtag_list
            hashtag_list.append(word[1:])
     
            hashtags = hashtags+","+word[1:]
            
    hash.append(hashtags)

# %%
count = 0
for i in hash:
    if(i==''):
        i = "N/A"
        hash[count] = i
        count+=1

# %%
codeswitched["hashtags"] = hash

# %%
codeswitched["hashtags"]
# Out:
# 0        N/A
# 1        N/A
# 2        N/A
# 3        N/A
# 4        N/A
#         ...
# 50170
# 50171
# 50172
# 50173
# 50174
# Name: hashtags, Length: 50175, dtype: object

# %%
df_hashtags = pd.DataFrame(hash)

# %%
df_hashtags.to_csv("Hashtags.csv")

# %%
df_hash = pd.read_csv("Hashtags.csv")

# %%
df_hash.head()
# Out:
#    Unnamed: 0    0
# 0           0  NaN
# 1           1  NaN
# 2           2  NaN
# 3           3  NaN
# 4           4  NaN

# %%
with open(r'Hashtags.txt', 'r') as infile, \
     open(r'Output.txt', 'w') as outfile:
    data = infile.read()
    data = data.replace('"', "")
    outfile.write(data)

# %%
row_count = 0
max_comma_count = 0
with open(r'Output.txt', 'r') as infile:
    for row in infile:
        comma_count = 0
        row_len = len(row)
        for i in range(row_len):
            if(row[i] == ","):
                comma_count+=1
            comma_difference = 28 - comma_count
        if(comma_count > max_comma_count):
            max_comma_count = comma_count
        
        row_count+=1
print (count)
print(max_comma_count)
# Out:
# 27182
# 28

# %%
s = ','
with open('Outputs.csv', 'w') as out_file:
    with open('Output.txt', 'r') as in_file:
        lines = in_file.readlines()
        row_count = 0
        for line in lines:
            row_count+=1
            comma_count = 0
            row_len = len(line)
            commas = ","
            for i in range(row_len):
                if(line[i] == ","):
                    comma_count+=1
            comma_diff = 28 - comma_count
            for i in range(comma_diff):
                commas = commas + ","
            
            out_file.write( commas+line)

# %%
outfile.close()
infile.close()
input_file.close()
output_file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-40e2794a2b64> in <module>
#       1 outfile.close()
#       2 infile.close()
# ----> 3 input_file.close()
#       4 output_file.close()
#
# NameError: name 'input_file' is not defined

# %%
pos = []
neg = []
neu = []
for tweet in tweets:
    score = SentimentIntensityAnalyzer().polarity_scores(tweet)
    pos.append(score['pos'])
    neg.append(score['neg'])
    neu.append(score['neu'])

# %%
codeswitched["Positive"] = pos
codeswitched["Negative"] = neg
codeswitched["Neutral"] = neu

# %%
codeswitched
# Out:
#        count  hate_speech  offensive_language  neither  class  \
# 0          3            1                   1        2      2
# 1          3            1                   1        2      2
# 2          3            1                   1        2      2
# 3          3            1                   1        2      2
# 4          3            1                   1        2      2
# ...      ...          ...                 ...      ...    ...
# 50170      4            2                   1        1      0
# 50171      4            2                   1        1      0
# 50172      5            3                   0        2      0
# 50173      4            2                   0        2      0
# 50174      4            3                   1        0      0
#
#                                                    tweet hashtags  Positive  \
# 0      kindly say bickering to kikuyus and kalenjins....      N/A     0.198
# ...

# %%
df_hashtags = pd.read_csv("Outputs.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,4,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_hashtags
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             NaN         NaN         NaN        NaN        NaN        NaN
# 1             NaN         NaN         NaN        NaN        NaN        NaN
# 2             NaN         NaN         NaN        NaN        NaN        NaN
# 3             NaN         NaN         NaN        NaN        NaN        NaN
# 4             NaN         NaN         NaN        NaN        NaN        NaN
# ...           ...         ...         ...        ...        ...        ...
# 50170         NaN         NaN         NaN        NaN        NaN        NaN
# 50171         NaN         NaN         NaN        NaN        NaN        NaN
# 50172         NaN         NaN         NaN        NaN        NaN        NaN
# 50173         NaN         NaN         NaN        NaN        NaN        NaN
# 50174         NaN         NaN         NaN        NaN        NaN        NaN
#
# ...

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(state_union.raw("2005-GWBush.txt"))

# %%
tokenized = custom_sent_tokenizer.tokenize("kindly say bickering to kikuyus and kalenjins")

# %%
blobed = TextBlob("kindly kikuyus, humble yourselves in 2022 and ")
for (a,b) in blobed.tags:
    print(a)
    print(b)
# Out:
# kindly
# RB
# kikuyus
# NN
# humble
# JJ
# yourselves
# NNS
# in
# IN
# 2022
# CD
# and
# CC

# %%
adj_cnt = 0
adv_cnt = 0
for tweet in tweets:
    adj_count = 0
    adv_count = 0
    blobed = TextBlob(tweet)
    counts = Counter(tag for word, tag in blobed.tags)
    adj_list = []
    adv_list = []
    adj_tag_list = ['JJ','JJR','JJS']
    adv_tag_list = ['RB','RBR','RBS']
    for (a,b) in blobed.tags:
        if b in adj_tag_list:
            adj_list.append(a)
            adj_count+=1
        elif b in adv_tag_list:
            adv_list.append(a)
            adj_count+=1
        else:
            pass
    adj_list.append(adj_count)
    adv_list.append(adv_count)

# %%
print(adj_list.count(0))
# Out:
# 0

# %%
#Text Cleaning
import spacy
spacy.blank("en")
from spacy.lang.en import English

parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from nltk.corpus import wordnet as wn

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    
    return WordNetLemmatizer().lemmatize(word)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
###Prepare data for topic modeling
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import random
text_data = []
count = 0
for tweet in tweets:
    tokens = prepare_text_for_lda(tweet)
    if random.random() > .99:
            
        count+=1
        text_data.append(tokens)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(text_data)
# Out:
# [['kikuyus', 'support', 'outcast', 'central', 'facing', 'ejection', 'secession', 'mbadilishe', 'majina', 'wajaluo', 'resist'], ['wakamba', 'dream', 'wedding', 'wanateta', 'appreciate'], ['celebrity', 'wazungu', 'mwanzo', 'kabisa', 'ukimwi'], ['saying', 'kikuyus', 'include', 'shall', 'william', 's.ruto', 'dive', 'plan', 'hamwezi', 'shall', 'bitter', 'truth', 'tribalists', 'shame'], ['luhyas', 'dilemma', 'political', 'leaders', 'choose', 'leaders', 'unite'], ['looter', 'walking', 'rotten', 'republic', 'SCREEN_NAME', 'SCREEN_NAME', 'SCREEN_NAME', 'SCREEN_NAME', 'SCREEN_NAME', 'SCREEN_NAME', 'SCREEN_NAME'], ['people', 'associate', 'corddemos', 'violent', 'believe'], ['simple', 'makaa', 'kutoka', 'kitui', 'kiambu', 'oppose', 'SCREEN_NAME', 'directive', 'charcoal', 'limuru', "murang'a", 'kiambu', 'nyeri', 'mafeelings', 'mpelekee', 'babayao', 'kamba', 'community'], ['SCREEN_NAME', 'SCREEN_NAME', 'outrage', 'bellicose', 'kandarara', 'alice', "ng'ang'a", 'assault', 'return', 'officer', 'elect
# ...

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pickle
pickle.dump(corpus, open('corpus.pkl','wb'))
dictionary.save('dictionary.gensim')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
####Find topics
import gensim
NUM_TOPICS = 2
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
topics = ldamodel.print_topics(num_words = 5)
for topic in topics:
    print(topic)
# Out:
# (0, '0.013*"SCREEN_NAME" + 0.012*"kikuyus" + 0.009*"noreformsnoelections" + 0.006*"kalenjins" + 0.006*"nyakundi"')
# (1, '0.037*"SCREEN_NAME" + 0.018*"kikuyus" + 0.007*"kenya" + 0.006*"uhuru" + 0.006*"kenyan"')
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')
import pyLDAvis
lda_display = pyLDAvis.gensim_models.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1573620406359823364552417166"></div>
# <script type="text/javascript">
#
# ...

# %%
from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer, SnowballStemmer
topic_one_score = []
topic_two_score = []
count = 0
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result
def lemmatize_stemming(text):
    return (WordNetLemmatizer().lemmatize(text, pos='v'))


for tweet in tweets:
    print("\n")
    unseen_document = tweet
    bow_vector = dictionary.doc2bow(preprocess(unseen_document))
    for index, score in sorted(ldamodel[bow_vector], key=lambda tup: -1*tup[1]):
        count+=1
        if("nyakundi" in ldamodel.print_topic(index, 5)):
            topic_two_score.append(score)
            print(ldamodel.print_topic(index, 5))
        else:
            topic_one_score.append(score)
            print(ldamodel.print_topic(index, 5))

# %%
print(topic_one_score)
# Out:
# [0.73704815, 0.86083585, 0.85880613, 0.70943344, 0.5683463, 0.5174697, 0.6893331, 0.7895936, 0.62792075, 0.7671865, 0.5554871, 0.5509204, 0.7319651, 0.8879201, 0.79731125, 0.9018169, 0.5442781, 0.9488015, 0.8978177, 0.6499624, 0.7081616, 0.59417987, 0.91632706, 0.83592, 0.61664474, 0.630552, 0.8721509, 0.88063604, 0.5427932, 0.860859, 0.717368, 0.9098202, 0.8681089, 0.56256086, 0.8721383, 0.5077976, 0.66762865, 0.7735961, 0.536274, 0.8714432, 0.50222677, 0.8640985, 0.85355246, 0.7307133, 0.662218, 0.7694622, 0.66945404, 0.5190841, 0.7562614, 0.84268177, 0.8883297, 0.5479394, 0.81418425, 0.7753959, 0.6783409, 0.66948193, 0.7753233, 0.83991015, 0.58220625, 0.72861195, 0.65052223, 0.56931096, 0.6176528, 0.7360969, 0.8584547, 0.8396581, 0.53484416, 0.88778716, 0.5924362, 0.6693773, 0.6072167, 0.6693894, 0.80832916, 0.7666127, 0.73348045, 0.82459205, 0.8961241, 0.5673096, 0.70237964, 0.8914479, 0.826125, 0.87217736, 0.66932094, 0.69875705, 0.58232564, 0.81474864, 0.9038169, 0.6692799, 0.8
# ...

# %%
count = 0
for topic in topics:
    count+=1
print(count)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 50175
